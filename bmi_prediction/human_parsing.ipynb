# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Human parsing for image preprocessing
# - download atr dataset and put it under `/checkpoints/atr.pth`

# %%
atr_dataset_url = 'https://drive.google.com/uc?id=1ruJg4lqR_jgQPj-9K0PP-L2vJERYOxLP'
gdown.download(atr_dataset_url, 'Self-Correction-Human-Parsing/checkpoints/atr.pth', quiet=False)

# %% [markdown]
# - start human parsing for images containing human body
#     - modify the `simple_extractor.py` for passing human body detection result as input
# - save output images in `process_images`

# %%
# !conda install -c conda-forge opencv
# !conda update ffmpeg

# %%
# !/anaconda/envs/azureml_py38_pytorch/bin/python Self-Correction-Human-Parsing/simple_extractor.py --dataset 'atr' --model-restore 'Self-Correction-Human-Parsing/checkpoints/atr.pth' --input-dir '../HKTVMall_data' --output-dir 'process_images' --input_csv '../human_detection/result/frcnn_result.csv'
# Out:
# Evaluating total class number 18 with ['Background', 'Hat', 'Hair', 'Sunglasses', 'Upper-clothes', 'Skirt', 'Pants', 'Dress', 'Belt', 'Left-shoe', 'Right-shoe', 'Face', 'Left-leg', 'Right-leg', 'Left-arm', 'Right-arm', 'Bag', 'Scarf']
# In total 207 images.
# ...
# 100%|█████████████████████████████████████████| 207/207 [02:39<00:00,  1.30it/s]
