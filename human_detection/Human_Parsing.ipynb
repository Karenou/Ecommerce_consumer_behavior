# %% [markdown]
# # Human parsing

# %% [markdown]
# - Mount the google drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install ninja
# !git clone https://github.com/PeikeLi/Self-Correction-Human-Parsing
# %cd Self-Correction-Human-Parsing
# !mkdir checkpoints
# !mkdir inputs
# !mkdir outputs
# Out:
# Collecting ninja
#   Downloading ninja-1.10.2.3-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (108 kB)
#      |████████████████████████████████| 108 kB 5.5 MB/s
# Installing collected packages: ninja
# Successfully installed ninja-1.10.2.3
# Cloning into 'Self-Correction-Human-Parsing'...
# remote: Enumerating objects: 719, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 719 (delta 3), reused 8 (delta 3), pack-reused 708
# Receiving objects: 100% (719/719), 3.80 MiB | 15.42 MiB/s, done.
# Resolving deltas: 100% (145/145), done.
# /content/Self-Correction-Human-Parsing

# %%
base_path = "/content/gdrive/MyDrive/RA"

# %% [markdown]
# - Select and download human dataset below

# %%
dataset = 'atr'         #select from ['lip', 'atr', 'pascal']

# %%
import gdown

if dataset == 'lip':
    url = 'https://drive.google.com/uc?id=1k4dllHpu0bdx38J7H28rVVLpU-kOHmnH'
elif dataset == 'atr':
    url = 'https://drive.google.com/uc?id=1ruJg4lqR_jgQPj-9K0PP-L2vJERYOxLP'
elif dataset == 'pascal':
    url = 'https://drive.google.com/uc?id=1E5YwNKW2VOEayK9mWCS3Kpsxf-3z04ZE'

output = 'checkpoints/final.pth'
gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ruJg4lqR_jgQPj-9K0PP-L2vJERYOxLP
# To: /content/Self-Correction-Human-Parsing/checkpoints/final.pth
# 100%|██████████| 267M/267M [00:01<00:00, 166MB/s]
# 'checkpoints/final.pth'

# %% [markdown]
# - Upload input image: I use the uploaded images on my own google drive

# %%
#Please select images which you want to upload
# %cd inputs
from google.colab import files
uploaded = files.upload()
# %cd ..
# Out:
# /content/Self-Correction-Human-Parsing/inputs
#      <input type="file" id="files-f8f64584-29fc-4bae-abfa-375e26eee9ea" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f8f64584-29fc-4bae-abfa-375e26eee9ea">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2.jpg to 2.jpg
# /content/Self-Correction-Human-Parsing

# %% [markdown]
# - Run and save processed images and pixel-wise logits on google drive

# %%
# !python3 simple_extractor.py --dataset 'atr' --model-restore 'checkpoints/final.pth' --input-dir "/content/gdrive/MyDrive/RA/HKTV_data"  --output-dir "/content/gdrive/MyDrive/RA/HKTV_data_process" --logits
# Out:
# Evaluating total class number 18 with ['Background', 'Hat', 'Hair', 'Sunglasses', 'Upper-clothes', 'Skirt', 'Pants', 'Dress', 'Belt', 'Left-shoe', 'Right-shoe', 'Face', 'Left-leg', 'Right-leg', 'Left-arm', 'Right-arm', 'Bag', 'Scarf']
# 100% 100/100 [02:58<00:00,  1.78s/it]

# %% [markdown]
# ## Detection criteria
# 1. More than 5% of pixels are classified as human labels
# 2. There are more than one detected human labels
#
# ## Performance on 100 images
# - Accuracy: 85%. Total time used: 3 min
# - Fail reasons:
#     - Most of the human body is covered by cloths: Image 73, 85, 141, 144, 151, 185, 203, 251, 258, 283, 757
#     - Human figure is too small: Image 23, 24
#     - Other weird scenarios: Image 96 (cannot recognize part of the arm); Image 102 (sport bra classified as human face)
# - **Pros**
#   - Easy to compute and understand, the pixel-wise logit is a by-product when going through the human-parsing phase in the BMI estimation model
# - **Cons**
#   1. Impractical, need to save the logits (~100MB for large image) of each image to disk, which consumes huge space when the number of images is huge
#   2. The pixel is related to actual size. So if the area of human figure is of small size compared to the image size, the threshold fails in such case
#   3. When most of the human body is covered by cloths, only small percentage of pixels are classified as human body. This method fails in such case. As the class labels of "atr" human dataset also contain some clothing labels - 'Hat', 'Upper-clothes', 'Skirt', 'Pants', 'Dress', 'Belt','Left-shoe', 'Right-shoe', 'Bag', 'Scarf', it is a trade-off to include these labels and improve recall, or to exclude these labels to improve precision.
#   4. Only a rule-based method, might not be generalized to all cases
#   5. The pixel threshold cannot guarantee that the part detected as human is clustered at a place, because pixel can be anywhere in the image, which is not meaningful in some cases

# %%
import pandas as pd
pd.set_option('display.max_rows', None)

import numpy as np
import glob

# %%
def count_pct_label_pixel(load_path, class_dict, label_name, print_shape=False):
    """
    count the percentage of pixels that are labeled as part of a person: [Hair, Face, Left-arm, Right-arm, Left-leg, Right-leg]
    """
    pixel_label = np.argmax(np.load(load_path), axis=2)

    if print_shape:
    print("Input shape is", pixel_label.shape)

    pct_pixel = 0
    if label_name == '':
    print("No classified human label.")
    else:
        n_pixel = len(np.where(pixel_label == class_dict[label_name])[0])
        total_pixel = pixel_label.shape[0] * pixel_label.shape[1]
        print("{:.2%} of pixels is classified as {}.".format(n_pixel /total_pixel, label_name))
        pct_pixel = n_pixel /total_pixel
  
    return pct_pixel

# %%
# sort the logits files by image id
output_paths = glob.glob('%s/HKTV_data_process/*.npy' % base_path)
output_paths.sort(key=lambda x: int(x.split("/")[-1].split(".")[0]))

# atr class labels
class_labels = np.array(['Background', 'Hat', 'Hair', 'Sunglasses', 'Upper-clothes', 'Skirt', 'Pants', 'Dress', 'Belt',
                       'Left-shoe', 'Right-shoe', 'Face', 'Left-leg', 'Right-leg', 'Left-arm', 'Right-arm', 'Bag', 'Scarf'])
class_dict = {name: label for label, name in enumerate(class_labels)}

# hair, face, left-leg, right-leg, left-arm, right-arm
human_labels = np.array([2, 11, 12, 13, 14, 15])

result_dict = {'image_id': [], 'contain_label': [], 'pct_pixel': [], 'par_pred': []}

for i in range(len(output_paths)):
    image_id = int(output_paths[i].split("/")[-1][:-4])
    print("Image %d" % image_id)
    pixel_label = np.argmax(np.load(output_paths[i]), axis=2)
    human_label = np.intersect1d(np.unique(pixel_label), human_labels)
    contain_label_list = class_labels[human_label]

    pct_total = 0
    for l in range(len(contain_label_list)):
        pct_total += count_pct_label_pixel(output_paths[i], class_dict, contain_label_list[l], print_shape=False)

    if pct_total > 0.05 and len(class_labels[human_label]) > 1:
        print("The image contains human. \n")
        result_dict["par_pred"].append(1)
    else:
        print("The image does not contains human. \n")
        result_dict["par_pred"].append(0)

    result_dict["image_id"].append(image_id)
    result_dict["contain_label"].append(", ".join(contain_label_list))
    result_dict["pct_pixel"].append(round(pct_total, 4))

result_df = pd.DataFrame.from_dict(result_dict, orient="columns")
result_df = result_df.sort_values("image_id").reset_index(drop=True)
result_df.to_csv("%s/human_parsing_result.csv" % base_path)
# Out:
# Image 0
# 0.01% of pixels is classified as Face.
# The image does not contains human.
#
# Image 1
# 0.04% of pixels is classified as Face.
# The image does not contains human.
#
# Image 2
# 0.89% of pixels is classified as Hair.
# 13.94% of pixels is classified as Face.
# 3.70% of pixels is classified as Left-leg.
# 3.50% of pixels is classified as Right-leg.
# 3.69% of pixels is classified as Left-arm.
# 4.36% of pixels is classified as Right-arm.
# The image contains human.
#
# Image 3
# 0.67% of pixels is classified as Hair.
# 18.69% of pixels is classified as Face.
# 2.34% of pixels is classified as Left-leg.
# 2.17% of pixels is classified as Right-leg.
# 4.22% of pixels is classified as Left-arm.
# 5.31% of pixels is classified as Right-arm.
# The image contains human.
#
# Image 5
# 0.93% of pixels is classified as Hair.
# 17.92% of pixels is classified as Face.
# 3.25% of pixels is classified as Left-leg.
# 3.27% of pixels is classified as Right-leg.
# 5.30% of pixels is classified as Left-arm.
# 5.03% of pixels is classified as Right-arm.
# The image contains human.
#
# Image 6
# 0.01% of pixels is classified as Hair.
# 55.77% of pixels is classified as Face.
# 0.31% of pixels is classified as Left-leg.
# 0.40% of pixels is classified as Right-leg.
# 0.75% of pixels is classified as Left-arm.
# 0.30% of pixels is classified as Right-arm.
# The image contains human.
#
# Image 7
# 0.97% of pixels is classified as Hair.
# 44.54% of pixels is classified as Face.
# 7.05% of pixels is classified as Left-arm.
# 2.89% of pixels is classified as Right-arm.
# The image contains human.
#
# Image 10
# 0.00% of pixels is classified as Left-arm.
# The image does not contains human.
#
# Image 16
# 0.06% of pixels is classified as Hair.
# 0.03% of pixels is classified as Face.
# 0.47% of pixels is classified as Right-arm.
# The image does not contains human.
#
# Image 21
# 7.03% of pixels is classified as Hair.
# 9.47% of pixels is classified as Face.
# The image contains human.
#
# Image 23
# 3.49% of pixels is classified as Hair.
# 0.41% of pixels is classified as Face.
# 0.00% of pixels is classified as Left-leg.
# The image does not contains human.
#
# Image 24
# 0.89% of pixels is classified as Hair.
# 1.09% of pixels is classified as Face.
# 0.52% of pixels is classified as Left-leg.
# 1.35% of pixels is classified as Left-arm.
# 0.20% of pixels is classified as Right-arm.
# The image does not contains human.
#
# Image 30
# 1.48% of pixels is classified as Face.
# The image does not contains human.
#
# Image 31
# 0.32% of pixels is classified as Hair.
# 0.91% of pixels is classified as Face.
# The image does not contains human.
#
# Image 40
# 0.01% of pixels is classified as Hair.
# 7.64% of pixels is classified as Face.
# 6.90% of pixels is classified as Left-arm.
# 7.78% of pixels is classified as Right-arm.
# The image contains human.
#
# Image 43
# 0.10% of pixels is classified as Hair.
# 6.47% of pixels is classified as Face.
# 0.05% of pixels is classified as Left-leg.
# 0.17% of pixels is classified as Right-leg.
# 8.27% of pixels is classified as Left-arm.
# 6.98% of pixels is classified as Right-arm.
# The image contains human.
#
# Image 44
# 0.08% of pixels is classified as Hair.
# 6.98% of pixels is classified as Face.
# 11.31% of pixels is classified as Left-arm.
# 3.75% of pixels is classified as Right-arm.
# The image contains human.
#
# Image 45
# 0.01% of pixels is classified as Hair.
# 27.57% of pixels is classified as Face.
# 0.62% of pixels is classified as Left-arm.
# 3.35% of pixels is classified as Right-arm.
# The image contains human.
#
# Image 46
# 4.32% of pixels is classified as Face.
# 2.48% of pixels is classified as Left-leg.
# 2.35% of pixels is classified as Right-leg.
# 5.13% of pixels is classified as Left-arm.
# 4.82% of pixels is classified as Right-arm.
# The image contains human.
#
# Image 47
# The image does not contains human.
#
# Image 48
# The image does not contains human.
#
# Image 49
# 0.12% of pixels is classified as Hair.
# 4.03% of pixels is classified as Face.
# 1.41% of pixels is classified as Left-leg.
# 2.25% of pixels is classified as Right-leg.
# 6.35% of pixels is classified as Left-arm.
# 4.46% of pixels is classified as Right-arm.
# The image contains human.
#
# Image 51
# 4.27% of pixels is classified as Face.
# 2.50% of pixels is classified as Left-leg.
# 2.36% of pixels is classified as Right-leg.
# 5.14% of pixels is classified as Left-arm.
# 4.89% of pixels is classified as Right-arm.
# The image contains human.
#
# Image 53
# 3.96% of pixels is classified as Face.
# 2.70% of pixels is classified as Left-leg.
# 2.66% of pixels is classified as Right-leg.
# 5.32% of pixels is classified as Left-arm.
# 5.22% of pixels is classified as Right-arm.
# The image contains human.
#
# Image 55
# 0.29% of pixels is classified as Hair.
# 0.86% of pixels is classified as Face.
# The image does not contains human.
#
# Image 56
# 0.39% of pixels is classified as Face.
# The image does not contains human.
#
# Image 60
# The image does not contains human.
#
# Image 63
# The image does not contains human.
#
# Image 73
# 1.46% of pixels is classified as Hair.
# 1.57% of pixels is classified as Face.
# 0.43% of pixels is classified as Left-leg.
# 0.39% of pixels is classified as Right-leg.
# 0.44% of pixels is classified as Left-arm.
# 0.43% of pixels is classified as Right-arm.
# The image does not contains human.
#
# Image 74
# 0.06% of pixels is classified as Hair.
# 0.81% of pixels is classified as Face.
# 2.13% of pixels is classified as Left-leg.
# 2.18% of pixels is classified as Right-leg.
# 1.04% of pixels is classified as Left-arm.
# 0.88% of pixels is classified as Right-arm.
# The image contains human.
#
# Image 83
# 0.06% of pixels is classified as Hair.
# 0.81% of pixels is classified as Face.
# 2.13% of pixels is classified as Left-leg.
# 2.18% of pixels is classified as Right-leg.
# 1.04% of pixels is classified as Left-arm.
# 0.88% of pixels is classified as Right-arm.
# The image contains human.
#
# Image 84
# 4.40% of pixels is classified as Hair.
# 3.25% of pixels is classified as Face.
# 4.07% of pixels is classified as Left-leg.
# 6.28% of pixels is classified as Right-leg.
# 1.65% of pixels is classified as Left-arm.
# 0.67% of pixels is classified as Right-arm.
# The image contains human.
#
# Image 85
# 1.60% of pixels is classified as Hair.
# 1.62% of pixels is classified as Face.
# 0.28% of pixels is classified as Left-leg.
# 0.12% of pixels is classified as Right-leg.
# 0.38% of pixels is classified as Right-arm.
# The image does not contains human.
#
# Image 86
# 4.96% of pixels is classified as Hair.
# 3.14% of pixels is classified as Face.
# 4.05% of pixels is classified as Left-leg.
# 5.40% of pixels is classified as Right-leg.
# 1.57% of pixels is classified as Left-arm.
# 1.39% of pixels is classified as Right-arm.
# The image contains human.
#
# Image 87
# 5.34% of pixels is classified as Hair.
# 1.09% of pixels is classified as Face.
# 0.12% of pixels is classified as Left-arm.
# The image contains human.
#
# Image 89
# 2.50% of pixels is classified as Hair.
# 1.73% of pixels is classified as Face.
# 0.83% of pixels is classified as Left-leg.
# 0.90% of pixels is classified as Right-leg.
# 0.44% of pixels is classified as Left-arm.
# 0.27% of pixels is classified as Right-arm.
# The image contains human.
#
# Image 92
# 14.73% of pixels is classified as Hair.
# 41.30% of pixels is classified as Face.
# The image contains human.
#
# Image 93
# The image does not contains human.
#
# Image 94
# 0.00% of pixels is classified as Hair.
# 0.33% of pixels is classified as Face.
# 0.04% of pixels is classified as Left-leg.
# 0.13% of pixels is classified as Right-leg.
# The image does not contains human.
#
# Image 96
# 0.00% of pixels is classified as Hair.
# 3.32% of pixels is classified as Face.
# 0.00% of pixels is classified as Left-leg.
# The image does not contains human.
#
# Image 102
# 1.55% of pixels is classified as Hair.
# 27.06% of pixels is classified as Face.
# 0.62% of pixels is classified as Left-arm.
# 0.04% of pixels is classified as Right-arm.
# The image contains human.
#
# Image 108
# 0.00% of pixels is classified as Hair.
# 0.97% of pixels is classified as Face.
# 0.29% of pixels is classified as Left-arm.
# The image does not contains human.
#
# Image 109
# 0.14% of pixels is classified as Face.
# The image does not contains human.
#
# Image 110
# 0.03% of pixels is classified as Hair.
# 0.61% of pixels is classified as Face.
# 0.02% of pixels is classified as Left-arm.
# 0.27% of pixels is classified as Right-arm.
# The image does not contains human.
#
# Image 112
# 24.93% of pixels is classified as Hair.
# 11.74% of pixels is classified as Face.
# 0.14% of pixels is classified as Left-arm.
# The image contains human.
#
# Image 121
# 0.00% of pixels is classified as Hair.
# 4.89% of pixels is classified as Face.
# The image does not contains human.
#
# Image 131
# 2.30% of pixels is classified as Hair.
# 2.60% of pixels is classified as Face.
# 1.02% of pixels is classified as Left-arm.
# 0.65% of pixels is classified as Right-arm.
# The image contains human.
#
# Image 132
# The image does not contains human.
#
# Image 141
# 0.23% of pixels is classified as Left-arm.
# 0.09% of pixels is classified as Right-arm.
# The image does not contains human.
#
# Image 143
# 0.12% of pixels is classified as Face.
# The image does not contains human.
#
# Image 144
# 0.77% of pixels is classified as Hair.
# 0.63% of pixels is classified as Face.
# 0.05% of pixels is classified as Left-arm.
# 0.23% of pixels is classified as Right-arm.
# The image does not contains human.
#
# Image 151
# 0.88% of pixels is classified as Hair.
# 0.78% of pixels is classified as Face.
# 0.11% of pixels is classified as Left-arm.
# 0.12% of pixels is classified as Right-arm.
# The image does not contains human.
#
# Image 152
# 4.79% of pixels is classified as Hair.
# 1.33% of pixels is classified as Face.
# The image contains human.
#
# Image 163
# The image does not contains human.
#
# Image 167
# The image does not contains human.
#
# Image 168
# 2.41% of pixels is classified as Hair.
# 2.76% of pixels is classified as Face.
# 1.00% of pixels is classified as Left-arm.
# 0.07% of pixels is classified as Right-arm.
# The image contains human.
#
# Image 181
# The image does not contains human.
#
# Image 185
# 0.55% of pixels is classified as Hair.
# 0.88% of pixels is classified as Face.
# 0.04% of pixels is classified as Right-arm.
# The image does not contains human.
#
# Image 203
# 0.66% of pixels is classified as Left-leg.
# 1.12% of pixels is classified as Right-leg.
# 0.09% of pixels is classified as Left-arm.
# 0.78% of pixels is classified as Right-arm.
# The image does not contains human.
#
# Image 204
# The image does not contains human.
#
# Image 217
# The image does not contains human.
#
# Image 230
# 1.58% of pixels is classified as Hair.
# 2.94% of pixels is classified as Face.
# 4.05% of pixels is classified as Left-arm.
# 1.13% of pixels is classified as Right-arm.
# The image contains human.
#
# Image 238
# The image does not contains human.
#
# Image 242
# 0.08% of pixels is classified as Hair.
# 0.19% of pixels is classified as Face.
# The image does not contains human.
#
# Image 251
# 2.62% of pixels is classified as Hair.
# 1.50% of pixels is classified as Face.
# 0.21% of pixels is classified as Right-arm.
# The image does not contains human.
#
# Image 254
# 2.71% of pixels is classified as Hair.
# 9.27% of pixels is classified as Face.
# 3.92% of pixels is classified as Left-arm.
# The image contains human.
#
# Image 255
# 0.70% of pixels is classified as Hair.
# 0.23% of pixels is classified as Face.
# The image does not contains human.
#
# Image 256
# 1.87% of pixels is classified as Hair.
# 1.10% of pixels is classified as Face.
# 0.32% of pixels is classified as Left-leg.
# 0.29% of pixels is classified as Left-arm.
# 1.54% of pixels is classified as Right-arm.
# The image contains human.
#
# Image 258
# 0.44% of pixels is classified as Hair.
# 0.86% of pixels is classified as Face.
# 0.25% of pixels is classified as Left-leg.
# 0.78% of pixels is classified as Right-leg.
# 0.60% of pixels is classified as Left-arm.
# 0.75% of pixels is classified as Right-arm.
# The image does not contains human.
#
# Image 260
# 0.99% of pixels is classified as Hair.
# 1.38% of pixels is classified as Face.
# The image does not contains human.
#
# Image 271
# 0.01% of pixels is classified as Hair.
# 2.25% of pixels is classified as Face.
# 1.00% of pixels is classified as Left-leg.
# 0.23% of pixels is classified as Right-leg.
# 2.81% of pixels is classified as Left-arm.
# 3.61% of pixels is classified as Right-arm.
# The image contains human.
#
# Image 277
# 7.92% of pixels is classified as Hair.
# 14.71% of pixels is classified as Face.
# 0.97% of pixels is classified as Left-leg.
# 0.21% of pixels is classified as Right-leg.
# 5.82% of pixels is classified as Left-arm.
# 2.96% of pixels is classified as Right-arm.
# The image contains human.
#
# Image 283
# 0.00% of pixels is classified as Hair.
# 0.01% of pixels is classified as Face.
# 0.37% of pixels is classified as Left-leg.
# 0.93% of pixels is classified as Right-leg.
# 0.02% of pixels is classified as Left-arm.
# 2.67% of pixels is classified as Right-arm.
# The image does not contains human.
#
# Image 286
# 1.94% of pixels is classified as Face.
# The image does not contains human.
#
# Image 289
# The image does not contains human.
#
# Image 295
# 0.02% of pixels is classified as Hair.
# 2.66% of pixels is classified as Face.
# 2.49% of pixels is classified as Left-arm.
# 1.84% of pixels is classified as Right-arm.
# The image contains human.
#
# Image 298
# 1.97% of pixels is classified as Hair.
# 0.63% of pixels is classified as Face.
# 2.31% of pixels is classified as Left-arm.
# 1.23% of pixels is classified as Right-arm.
# The image contains human.
#
# Image 300
# 0.09% of pixels is classified as Face.
# The image does not contains human.
#
# Image 308
# 1.76% of pixels is classified as Hair.
# 3.23% of pixels is classified as Face.
# 0.68% of pixels is classified as Left-arm.
# 1.24% of pixels is classified as Right-arm.
# The image contains human.
#
# Image 309
# 0.01% of pixels is classified as Face.
# 0.02% of pixels is classified as Right-arm.
# The image does not contains human.
#
# Image 311
# 0.01% of pixels is classified as Face.
# The image does not contains human.
#
# Image 320
# The image does not contains human.
#
# Image 325
# The image does not contains human.
#
# Image 337
# 0.87% of pixels is classified as Hair.
# 0.00% of pixels is classified as Face.
# The image does not contains human.
#
# Image 342
# 6.83% of pixels is classified as Hair.
# 28.43% of pixels is classified as Face.
# 5.33% of pixels is classified as Left-arm.
# 9.29% of pixels is classified as Right-arm.
# The image contains human.
#
# Image 344
# 6.42% of pixels is classified as Hair.
# 21.71% of pixels is classified as Face.
# 7.47% of pixels is classified as Left-arm.
# 2.23% of pixels is classified as Right-arm.
# The image contains human.
#
# Image 349
# 0.07% of pixels is classified as Hair.
# 2.25% of pixels is classified as Face.
# The image does not contains human.
#
# Image 351
# 0.09% of pixels is classified as Hair.
# 0.10% of pixels is classified as Face.
# The image does not contains human.
#
# Image 361
# 3.01% of pixels is classified as Hair.
# 4.88% of pixels is classified as Face.
# 2.37% of pixels is classified as Left-arm.
# 2.15% of pixels is classified as Right-arm.
# The image contains human.
#
# Image 365
# The image does not contains human.
#
# Image 370
# The image does not contains human.
#
# Image 443
# 0.71% of pixels is classified as Hair.
# 3.01% of pixels is classified as Face.
# 0.46% of pixels is classified as Left-leg.
# 0.01% of pixels is classified as Right-leg.
# 0.76% of pixels is classified as Left-arm.
# 0.44% of pixels is classified as Right-arm.
# The image contains human.
#
# Image 484
# 3.27% of pixels is classified as Hair.
# 1.70% of pixels is classified as Face.
# 0.93% of pixels is classified as Left-leg.
# 0.84% of pixels is classified as Right-leg.
# 2.74% of pixels is classified as Left-arm.
# The image contains human.
#
# Image 487
# 0.42% of pixels is classified as Hair.
# 1.16% of pixels is classified as Face.
# 1.38% of pixels is classified as Left-leg.
# 1.91% of pixels is classified as Right-leg.
# 0.76% of pixels is classified as Left-arm.
# 0.86% of pixels is classified as Right-arm.
# The image contains human.
#
# Image 497
# 0.01% of pixels is classified as Hair.
# The image does not contains human.
#
# Image 633
# 0.02% of pixels is classified as Hair.
# 9.74% of pixels is classified as Face.
# 2.58% of pixels is classified as Left-leg.
# 3.90% of pixels is classified as Left-arm.
# 0.55% of pixels is classified as Right-arm.
# The image contains human.
#
# Image 688
# 9.17% of pixels is classified as Hair.
# 20.60% of pixels is classified as Face.
# The image contains human.
#
# Image 721
# The image does not contains human.
#
# Image 742
# The image does not contains human.
#
# Image 757
# 0.00% of pixels is classified as Hair.
# 0.24% of pixels is classified as Face.
# 3.09% of pixels is classified as Left-arm.
# 0.20% of pixels is classified as Right-arm.
# The image does not contains human.

# %%
result_df
# Out:
#     image_id  ... has_human
# 0          0  ...         0
# 1          1  ...         0
# 2          2  ...         1
# 3          3  ...         1
# 4          5  ...         1
# 5          6  ...         1
# 6          7  ...         1
# 7         10  ...         0
# 8         16  ...         0
# 9         21  ...         1
# 10        23  ...         0
# 11        24  ...         0
# 12        30  ...         0
# 13        31  ...         0
# 14        40  ...         1
# 15        43  ...         1
# 16        44  ...         1
# 17        45  ...         1
# 18        46  ...         1
# 19        47  ...         0
# 20        48  ...         0
# 21        49  ...         1
# 22        51  ...         1
# 23        53  ...         1
# 24        55  ...         0
# 25        56  ...         0
# 26        60  ...         0
# 27        63  ...         0
# 28        73  ...         0
# 29        74  ...         1
# 30        83  ...         1
# 31        84  ...         1
# 32        85  ...         0
# 33        86  ...         1
# 34        87  ...         1
# 35        89  ...         1
# 36        92  ...         1
# 37        93  ...         0
# 38        94  ...         0
# 39        96  ...         0
# 40       102  ...         1
# 41       108  ...         0
# 42       109  ...         0
# 43       110  ...         0
# 44       112  ...         1
# 45       121  ...         0
# 46       131  ...         1
# 47       132  ...         0
# 48       141  ...         0
# 49       143  ...         0
# 50       144  ...         0
# 51       151  ...         0
# 52       152  ...         1
# 53       163  ...         0
# 54       167  ...         0
# 55       168  ...         1
# 56       181  ...         0
# 57       185  ...         0
# 58       203  ...         0
# 59       204  ...         0
# 60       217  ...         0
# 61       230  ...         1
# 62       238  ...         0
# 63       242  ...         0
# 64       251  ...         0
# 65       254  ...         1
# 66       255  ...         0
# 67       256  ...         1
# 68       258  ...         0
# 69       260  ...         0
# 70       271  ...         1
# 71       277  ...         1
# 72       283  ...         0
# 73       286  ...         0
# 74       289  ...         0
# 75       295  ...         1
# 76       298  ...         1
# 77       300  ...         0
# 78       308  ...         1
# 79       309  ...         0
# 80       311  ...         0
# 81       320  ...         0
# 82       325  ...         0
# 83       337  ...         0
# 84       342  ...         1
# 85       344  ...         1
# 86       349  ...         0
# 87       351  ...         0
# 88       361  ...         1
# 89       365  ...         0
# 90       370  ...         0
# 91       443  ...         1
# 92       484  ...         1
# 93       487  ...         1
# 94       497  ...         0
# 95       633  ...         1
# 96       688  ...         1
# 97       721  ...         0
# 98       742  ...         0
# 99       757  ...         0
#
# [100 rows x 4 columns]
